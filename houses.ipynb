# %% [markdown]
# ## Environment Management
# Project Environment Name: California_Houses
# Project Directory Name: california_houses_prj

# %%
# Make sure Jupiter runs at the correct environment to avoid conflicts:
import sys
sys.executable
# Out:
# 'C:\\Users\\Adespotos\\anaconda3\\envs\\California_Houses\\python.exe'

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Cleaning

# %%
# Import the excel file skipping the first 3 rows containing irrelevant information:
data = pd.read_excel("2.13.+Practical+example.+Descriptive+statistics_lesson.xlsx", skiprows=3)

# %%
data.head(10)
# Out:
#   Unnamed: 0 Product Unnamed: 2    Unnamed: 3     Unnamed: 4  \
# 0        NaN      ID   Building  Year of sale  Month of sale
# 1        NaN    1030          1          2005             11
# 2        NaN    1029          1          2005             10
# 3        NaN    2002          2          2007              7
# 4        NaN    2031          2          2007             12
# 5        NaN    1049          1          2004             11
# 6        NaN    3011          3          2007              9
# 7        NaN    3026          3          2007              9
# 8        NaN    3023          3          2008              1
# 9        NaN    1031          1          2006              6
#
#          Unnamed: 5  Unnamed: 6  Unnamed: 7   Unnamed: 8 Unnamed: 9  ...  \
# 0  Type of property  Property #  Area (ft.)        Price     Status  ...
# 1         Apartment          30    743.0856   246172.676       Sold  ...
# 2         Apartment          29    756.2128   246331.904       Sold  ...
# 3         Apartment           2    587.2808  209280.9104       Sold  ...
# 4         Apartment          31   1604.7464  452667.0064       Sold  ...
# 5         Apartment          49   1375.4508  467083.3132       Sold  ...
# 6         Apartment          11      675.19    203491.85       Sold  ...
# 7         Apartment          26     670.886   212520.826       Sold  ...
# 8         Apartment          23    720.8124  198591.8488       Sold  ...
# 9         Apartment          31     782.252    265467.68       Sold  ...
#
#    Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22  \
# 0            Y           M           D      Gender     Country       State
# 1         1986           6          21           F         USA  California
# 2         1983           2        24.0           F         USA  California
# 3         1985          12          27           M         USA  California
# 4         1985          12          27           M         USA  California
# 5         1979           5          15           F         USA  California
# 6         1981          12          26           F         USA    Virginia
# 7         1981          12          26           F         USA    Virginia
# 8         1982           5          27           M         USA  California
# 9         1979           6          27           M         USA     Arizona
#
#   Unnamed: 23        Unnamed: 24 Unnamed: 25 Unnamed: 26
# 0     Purpose  Deal satisfaction    Mortgage      Source
# 1        Home                  5          No     Website
# 2        Home                  5          No     Website
# 3        Home                  1         Yes      Client
# 4  Investment                  3         Yes     Website
# 5        Home                  4          No      Agency
# 6  Investment                  5          No      Client
# 7  Investment                  5          No      Agency
# 8        Home                  5          No      Client
# 9        Home                  2         Yes     Website
#
# [10 rows x 27 columns]

# %%
# Fix the column names:
data.columns = data.iloc[0]

# %%
# Investigate:
print(data.info())
data.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268 entries, 0 to 267
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   nan                      1 non-null      object
#  1   ID                       268 non-null    object
#  2   Building                 268 non-null    object
#  3   Year of sale             196 non-null    object
#  4   Month of sale            196 non-null    object
#  5   Type of property         268 non-null    object
#  6   Property #               268 non-null    object
#  7   Area (ft.)               268 non-null    object
#  8   Price                    268 non-null    object
#  9   Status                   196 non-null    object
#  10  nan                      0 non-null      float64
#  11  Customer ID              196 non-null    object
#  12  Entity                   196 non-null    object
#  13  Name                     196 non-null    object
#  14  Surname                  196 non-null    object
#  15  Age at time of purchase  180 non-null    object
#  16  Interval                 179 non-null    object
#  17  Y                        179 non-null    object
#  18  M                        179 non-null    object
#  19  D                        179 non-null    object
#  20  Gender                   179 non-null    object
#  21  Country                  196 non-null    object
#  22  State                    182 non-null    object
#  23  Purpose                  196 non-null    object
#  24  Deal satisfaction        196 non-null    object
#  25  Mortgage                 196 non-null    object
#  26  Source                   196 non-null    object
# dtypes: float64(1), object(26)
# memory usage: 56.7+ KB
# None
# 0  NaN    ID  Building  Year of sale  Month of sale  Type of property  \
# 0  NaN    ID  Building  Year of sale  Month of sale  Type of property
# 1  NaN  1030         1          2005             11         Apartment
# 2  NaN  1029         1          2005             10         Apartment
# 3  NaN  2002         2          2007              7         Apartment
# 4  NaN  2031         2          2007             12         Apartment
# 5  NaN  1049         1          2004             11         Apartment
# 6  NaN  3011         3          2007              9         Apartment
# 7  NaN  3026         3          2007              9         Apartment
# 8  NaN  3023         3          2008              1         Apartment
# 9  NaN  1031         1          2006              6         Apartment
#
# 0  Property #  Area (ft.)        Price  Status  ...     Y   M     D  Gender  \
# 0  Property #  Area (ft.)        Price  Status  ...     Y   M     D  Gender
# 1          30    743.0856   246172.676    Sold  ...  1986   6    21       F
# 2          29    756.2128   246331.904    Sold  ...  1983   2  24.0       F
# 3           2    587.2808  209280.9104    Sold  ...  1985  12    27       M
# 4          31   1604.7464  452667.0064    Sold  ...  1985  12    27       M
# 5          49   1375.4508  467083.3132    Sold  ...  1979   5    15       F
# 6          11      675.19    203491.85    Sold  ...  1981  12    26       F
# 7          26     670.886   212520.826    Sold  ...  1981  12    26       F
# 8          23    720.8124  198591.8488    Sold  ...  1982   5    27       M
# 9          31     782.252    265467.68    Sold  ...  1979   6    27       M
#
# 0  Country       State     Purpose  Deal satisfaction  Mortgage   Source
# 0  Country       State     Purpose  Deal satisfaction  Mortgage   Source
# 1      USA  California        Home                  5        No  Website
# 2      USA  California        Home                  5        No  Website
# 3      USA  California        Home                  1       Yes   Client
# 4      USA  California  Investment                  3       Yes  Website
# 5      USA  California        Home                  4        No   Agency
# 6      USA    Virginia  Investment                  5        No   Client
# 7      USA    Virginia  Investment                  5        No   Agency
# 8      USA  California        Home                  5        No   Client
# 9      USA     Arizona        Home                  2       Yes  Website
#
# [10 rows x 27 columns]

# %% [raw]
# The previous cell contains two 'nan' columns that are unexpected.

# %%
# Drop the first row and any columns containing only NaN values.
data = data.iloc[1:].dropna(axis=1, how="all")

# %%
# Investigate further:
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 1 to 267
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   nan                      1 non-null      object
#  1   ID                       267 non-null    object
#  2   Building                 267 non-null    object
#  3   Year of sale             195 non-null    object
#  4   Month of sale            195 non-null    object
#  5   Type of property         267 non-null    object
#  6   Property #               267 non-null    object
#  7   Area (ft.)               267 non-null    object
#  8   Price                    267 non-null    object
#  9   Status                   195 non-null    object
#  10  Customer ID              195 non-null    object
#  11  Entity                   195 non-null    object
#  12  Name                     195 non-null    object
#  13  Surname                  195 non-null    object
#  14  Age at time of purchase  179 non-null    object
#  15  Interval                 178 non-null    object
#  16  Y                        178 non-null    object
#  17  M                        178 non-null    object
#  18  D                        178 non-null    object
#  19  Gender                   178 non-null    object
#  20  Country                  195 non-null    object
#  21  State                    181 non-null    object
#  22  Purpose                  195 non-null    object
#  23  Deal satisfaction        195 non-null    object
#  24  Mortgage                 195 non-null    object
#  25  Source                   195 non-null    object
# dtypes: object(26)
# memory usage: 54.4+ KB

# %%
# Drop the second 'nan' column and reset the index:
data = data.dropna(axis=1, thresh=2).reset_index(drop=True)

# %%
# The final column number should be 25:
print(data.info())
data.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       267 non-null    object
#  1   Building                 267 non-null    object
#  2   Year of sale             195 non-null    object
#  3   Month of sale            195 non-null    object
#  4   Type of property         267 non-null    object
#  5   Property #               267 non-null    object
#  6   Area (ft.)               267 non-null    object
#  7   Price                    267 non-null    object
#  8   Status                   195 non-null    object
#  9   Customer ID              195 non-null    object
#  10  Entity                   195 non-null    object
#  11  Name                     195 non-null    object
#  12  Surname                  195 non-null    object
#  13  Age at time of purchase  179 non-null    object
#  14  Interval                 178 non-null    object
#  15  Y                        178 non-null    object
#  16  M                        178 non-null    object
#  17  D                        178 non-null    object
#  18  Gender                   178 non-null    object
#  19  Country                  195 non-null    object
#  20  State                    181 non-null    object
#  21  Purpose                  195 non-null    object
#  22  Deal satisfaction        195 non-null    object
#  23  Mortgage                 195 non-null    object
#  24  Source                   195 non-null    object
# dtypes: object(25)
# memory usage: 52.3+ KB
# None
# 0    ID Building Year of sale Month of sale Type of property Property #  \
# 0  1030        1         2005            11        Apartment         30
# 1  1029        1         2005            10        Apartment         29
# 2  2002        2         2007             7        Apartment          2
# 3  2031        2         2007            12        Apartment         31
# 4  1049        1         2004            11        Apartment         49
# 5  3011        3         2007             9        Apartment         11
# 6  3026        3         2007             9        Apartment         26
# 7  3023        3         2008             1        Apartment         23
# 8  1031        1         2006             6        Apartment         31
# 9  4023        4         2006             3        Apartment         23
#
# 0 Area (ft.)        Price Status Customer ID  ...     Y   M     D Gender  \
# 0   743.0856   246172.676   Sold       C0028  ...  1986   6    21      F
# 1   756.2128   246331.904   Sold       C0027  ...  1983   2  24.0      F
# 2   587.2808  209280.9104   Sold       C0112  ...  1985  12    27      M
# 3  1604.7464  452667.0064   Sold       C0160  ...  1985  12    27      M
# 4  1375.4508  467083.3132   Sold       C0014  ...  1979   5    15      F
# 5     675.19    203491.85   Sold       C0125  ...  1981  12    26      F
# 6    670.886   212520.826   Sold       C0125  ...  1981  12    26      F
# 7   720.8124  198591.8488   Sold       C0166  ...  1982   5    27      M
# 8    782.252    265467.68   Sold       C0034  ...  1979   6    27      M
# 9   794.5184  235633.2592   Sold       C0170  ...  1979  12     3      F
#
# 0 Country       State     Purpose Deal satisfaction Mortgage   Source
# 0     USA  California        Home                 5       No  Website
# 1     USA  California        Home                 5       No  Website
# 2     USA  California        Home                 1      Yes   Client
# 3     USA  California  Investment                 3      Yes  Website
# 4     USA  California        Home                 4       No   Agency
# 5     USA    Virginia  Investment                 5       No   Client
# 6     USA    Virginia  Investment                 5       No   Agency
# 7     USA  California        Home                 5       No   Client
# 8     USA     Arizona        Home                 2      Yes  Website
# 9     USA    Virginia  Investment                 3      Yes   Agency
#
# [10 rows x 25 columns]

# %% [markdown]
# The data preparation is completed allowing to proceed with further analysis.

# %%
print("ID Column Categories:", len(data["ID"].value_counts()), "ID Column NaN Values:", data["ID"].isna().any(), 
     "Customer ID Column Categories:", len(data["Customer ID"].value_counts()), "Customer ID Column NaN Values:", data["Customer ID"].isna().any(),
     "Property Column Categories:", len(data["Property #"].value_counts()), "Property # Column NaN Values:", data["Property #"].isna().any())
# Out:
# ID Column Categories: 240 ID Column NaN Values: False Customer ID Column Categories: 162 Customer ID Column NaN Values: True Property Column Categories: 102 Property # Column NaN Values: False

# %% [markdown]
# The columns "ID", "Customer ID", and "Property #" appear to have high cardinality and may not be unique identifiers based on the available data. It's difficult to completely determine their purpose without additional context. However, "ID" likely represents a sale ID, while "Customer ID" clearly indicates customer identification. The meaning of "Property #" remains unclear.

# %%
# Check the duplicate IDs information:
duplicate_id = data["ID"].value_counts()[lambda x: x > 1].index
duplicate_id_indices = data[data["ID"].isin(duplicate_id)].index
data.loc[duplicate_id_indices].sort_values("ID")
# Out:
# 0      ID Building Year of sale Month of sale Type of property Property #  \
# 196  1002        1          NaN           NaN        Apartment          2
# 137  1002        1         2004             3           Office          2
# 49   1003        1         2005             6           Office          3
# 197  1003        1          NaN           NaN           Office          3
# 198  1008        1          NaN           NaN        Apartment          8
# 184  1008        1         2005            12           Office          8
# 181  1009        1         2004            11           Office         10
# 180  1009        1         2004            11           Office          9
# 199  1019        1          NaN           NaN        Apartment         19
# 189  1019        1         2005             7        Apartment         19
# 195  1042        1         2005             7        Apartment         42
# 200  1042        1          NaN           NaN        Apartment         42
# 15   1047        1         2007            12        Apartment         47
# 201  1047        1          NaN           NaN        Apartment         47
# 203  2052        2          NaN           NaN        Apartment         52
# 149  2052        2         2007             3        Apartment         52
# 112  3007        3         2006            10        Apartment          7
# 205  3007        3          NaN           NaN        Apartment          7
# 19   3029        3         2007             4        Apartment         29
# 207  3029        3          NaN           NaN        Apartment         29
# 29   3031        3         2007             3        Apartment         31
# 208  3031        3          NaN           NaN        Apartment         31
# 69   3038        3         2007             5        Apartment         38
# 209  3038        3          NaN           NaN        Apartment         38
# 76   3049        3         2007             4        Apartment         49
# 210  3049        3          NaN           NaN        Apartment         49
# 139  3050        3         2006            11        Apartment         50
# 211  3050        3          NaN           NaN        Apartment         50
# 217  4013        4          NaN           NaN        Apartment         13
# 48   4013        4         2007             1        Apartment         13
# 222  4023        4          NaN           NaN        Apartment         23
# 9    4023        4         2006             3        Apartment         23
# 125  4029        4         2007            11        Apartment         29
# 225  4029        4          NaN           NaN        Apartment         29
# 92   4034        4         2007            10        Apartment         34
# 228  4034        4          NaN           NaN        Apartment         34
# 89   4049        4         2008             1        Apartment         49
# 234  4049        4          NaN           NaN        Apartment         49
# 61   5016        5         2007             6        Apartment         16
# 248  5016        5          NaN           NaN        Apartment         16
# 252  5025        5          NaN           NaN        Apartment         25
# 110  5025        5         2008            12        Apartment         25
# 254  5030        5          NaN           NaN        Apartment         30
# 116  5030        5         2010             5        Apartment         30
# 256  5034        5          NaN           NaN        Apartment         34
# 157  5034        5         2007            10        Apartment         34
# 257  5036        5          NaN           NaN        Apartment         36
# 155  5036        5         2007            11        Apartment         36
# 154  5041        5         2007            11        Apartment         41
# 260  5041        5          NaN           NaN        Apartment         41
# 140  5050        5         2007            11        Apartment         50
# 265  5050        5          NaN           NaN        Apartment         50
# 16   5051        5         2006             3        Apartment         51
# 266  5051        5          NaN           NaN        Apartment         51
#
# 0   Area (ft.)        Price Status Customer ID  ...     Y    M    D Gender  \
# 196  1238.5836   400865.916    NaN         NaN  ...   NaN  NaN  NaN    NaN
#
NaN         NaN  ...   NaN  NaN  NaN    NaN
# 140  1093.0008  390494.2712   Sold       C0140  ...  1950   15    2      F
# 265  1074.7088  365868.7776    NaN         NaN  ...   NaN  NaN  NaN    NaN
# 16    790.5372  249591.9948   Sold       C0171  ...  1977   12   25      M
# 266    789.246   199216.404    NaN         NaN  ...   NaN  NaN  NaN    NaN
#
# 0   Country       State     Purpose Deal satisfaction Mortgage   Source
# 196     NaN         NaN         NaN               NaN      NaN      NaN
# 137     USA  California  Investment                 5      Yes  Website
# 49      USA     Arizona        Home                 1      Yes  Website
# 197     NaN         NaN         NaN               NaN      NaN      NaN
# 198     NaN         NaN         NaN               NaN      NaN      NaN
# 184     USA  California  Investment                 1      Yes  Website
# 181     USA      Nevada  Investment                 4       No  Website
# 180     USA      Nevada  Investment                 5       No  Website
# 199     NaN         NaN         NaN               NaN      NaN      NaN
# 189    USA   California  Investment                 5       No  Website
# 195    USA   California  Investment                 5       No  Website
# 200     NaN         NaN         NaN               NaN      NaN      NaN
# 15      USA  California        Home                 5       No  Website
# 201     NaN         NaN         NaN               NaN      NaN      NaN
# 203     NaN         NaN         NaN               NaN      NaN      NaN
# 149  Canada         NaN  Investment                 5       No  Website
# 112     USA  California  Investment                 5       No   Agency
# 205     NaN         NaN         NaN               NaN      NaN      NaN
# 19      USA     Arizona        Home                 3       No   Client
# 207     NaN         NaN         NaN               NaN      NaN      NaN
# 29      USA  California  Investment                 4       No   Client
# 208     NaN         NaN         NaN               NaN      NaN      NaN
# 69      USA  California        Home                 4       No  Website
# 209     NaN         NaN         NaN               NaN      NaN      NaN
# 76   Mexico         NaN        Home                 3       No   Agency
# 210     NaN         NaN         NaN               NaN      NaN      NaN
# 139  Russia         NaN        Home                 3      Yes   Agency
# 211     NaN         NaN         NaN               NaN      NaN      NaN
# 217     NaN         NaN         NaN               NaN      NaN      NaN
# 48      USA    Colorado        Home                 2       No   Agency
# 222     NaN         NaN         NaN               NaN      NaN      NaN
# 9       USA    Virginia  Investment                 3      Yes   Agency
# 125     USA  California        Home                 4      Yes  Website
# 225     NaN         NaN         NaN               NaN      NaN      NaN
# 92      USA  California        Home                 1      Yes  Website
# 228     NaN         NaN         NaN               NaN      NaN      NaN
# 89      USA  California        Home                 5       No   Client
# 234     NaN         NaN         NaN               NaN      NaN      NaN
# 61      USA      Oregon  Investment                 2       No   Client
# 248     NaN         NaN         NaN               NaN      NaN      NaN
# 252     NaN         NaN         NaN               NaN      NaN      NaN
# 110     USA  California  Investment                 5      Yes   Agency
# 254     NaN         NaN         NaN               NaN      NaN      NaN
# 116     USA      Nevada        Home                 3      Yes  Website
# 256     NaN         NaN         NaN               NaN      NaN      NaN
# 157     USA     Arizona        Home                 4       No  Website
# 257     NaN         NaN         NaN               NaN      NaN      NaN
# 155     USA  California        Home                 4      Yes  Website
# 154     USA  California  Investment                 4       No   Agency
# 260     NaN         NaN         NaN               NaN      NaN      NaN
# 140     USA      Nevada        Home                 3       No  Website
# 265     NaN         NaN         NaN               NaN      NaN      NaN
# 16      USA      Nevada        Home                 4      Yes  Website
# 266     NaN         NaN         NaN               NaN      NaN      NaN
#
# [54 rows x 25 columns]

# %% [markdown]
# A significant number of missing values make it difficult to draw conclusions from the data. There are a lot of missing values which do not allow for comparisons. The ID column probably represents a sale ID because of the information of 1009 ID, which suggests there are two different houses sold at the same date. In addition, the property number as well as the area of the houses are different which suggests the same thing.

# %%
# Change dtype in order for the code below to work:
data["Property #"] = data["Property #"].astype(int)

# Check the duplicate 'Property #' column's information:
duplicate_property = data["Property #"].value_counts()[lambda x: x > 1].index
duplicate_property_indices = data[data["Property #"].isin(duplicate_property)].index
data.loc[duplicate_property_indices].sort_values("Property #").head(13)
# Out:
# 0      ID Building Year of sale Month of sale Type of property  Property #  \
# 86   3001        3         2007             8        Apartment           1
# 186  2001        2         2004             3        Apartment           1
# 168  3002        3         2007             8        Apartment           2
# 196  1002        1          NaN           NaN        Apartment           2
# 215  4002        4          NaN           NaN        Apartment           2
# 137  1002        1         2004             3           Office           2
# 235  5002        5          NaN           NaN        Apartment           2
# 2    2002        2         2007             7        Apartment           2
# 98   3003        3         2007            11        Apartment           3
# 114  2003        2         2006            12        Apartment           3
# 236  5003        5          NaN           NaN        Apartment           3
# 197  1003        1          NaN           NaN           Office           3
# 49   1003        1         2005             6           Office           3
#
# 0   Area (ft.)        Price Status Customer ID  ...     Y    M     D Gender  \
# 86    579.7488  171262.6544   Sold       C0069  ...  1963   11     5      M
# 186   587.2808  169158.2944   Sold       C0121  ...   NaN  NaN   NaN    NaN
# 168    923.208   261871.696   Sold       C0115  ...  1938   10  29.0      M
# 196  1238.5836   400865.916    NaN         NaN  ...   NaN  NaN   NaN    NaN
# 215    789.246   231348.928    NaN         NaN  ...   NaN  NaN   NaN    NaN
# 137  1238.5836  410932.6732   Sold       C0002  ...  1947    2    13      M
# 235  1273.8764  413761.7064    NaN         NaN  ...   NaN  NaN   NaN    NaN
# 2     587.2808  209280.9104   Sold       C0112  ...  1985   12    27      M
# 98      675.19     233142.8   Sold       C0141  ...  1960   10     1      F
# 114   927.0816  289727.9904   Sold       C0063  ...  1955   12     2      M
# 236   798.4996  212644.3948    NaN         NaN  ...   NaN  NaN   NaN    NaN
# 197   713.7108  217787.7104    NaN         NaN  ...   NaN  NaN   NaN    NaN
# 49    717.0464  193660.6208   Sold       C0022  ...  1967    4    13      M
#
# 0   Country       State     Purpose Deal satisfaction Mortgage   Source
# 86      USA  California  Investment                 5       No  Website
# 186     USA  California        Home                 3      Yes  Website
# 168     USA  California        Home                 5       No  Website
# 196     NaN         NaN         NaN               NaN      NaN      NaN
# 215     NaN         NaN         NaN               NaN      NaN      NaN
# 137     USA  California  Investment                 5      Yes  Website
# 235     NaN         NaN         NaN               NaN      NaN      NaN
# 2       USA  California        Home                 1      Yes   Client
# 98      USA  California  Investment                 1      Yes   Agency
# 114  Russia         NaN  Investment                 3       No   Agency
# 236     NaN         NaN         NaN               NaN      NaN      NaN
# 197     NaN         NaN         NaN               NaN      NaN      NaN
# 49      USA     Arizona        Home                 1      Yes  Website
#
# [13 rows x 25 columns]

# %% [markdown]
# The above cell of code doesn't help neither. The results show unambiguity. Let's proceed to another part of the data table.

# %%
print("Column NaN values:", data["Building"].isna().any())
data["Building"].value_counts()
# Out:
# Column NaN values: False
# Building
# 3    63
# 2    57
# 1    52
# 5    52
# 4    43
# Name: count, dtype: int64

# %% [markdown]
# This is a categorical column that divides the buildings into distinct categories and has no missing values (NaN). The data.info() output reveals that these categories are not related to the "Type of property" column. They represent a different categorical classification and their integer type likely has no physical meaning. Since they represent categories, categorical data types are generally more memory-efficient than both object and integer types. Let's create a simple function to demonstrate this.

# %%
def memory_calculation(table):
    memory = data.memory_usage().sum()
    print(f"Total Memory: {memory} bytes")
memory_calculation(table=data)
# Out:
# Total Memory: 52464 bytes

# %%
# Fix the type of the column and recheck the memory:
data["Building"] = data["Building"].astype("category")
memory_calculation(table=data)
# Out:
# Total Memory: 50807 bytes

# %% [markdown]
# These cells were created only for testing purposes. The dtypes will be changed again later on this project.

# %%
# Make some checks on some other columns:
print("'Year of sale' Non NaN Values:", data["Year of sale"].value_counts().sum(), 
      "'Month of sale' Non NaN Values:", data["Month of sale"].value_counts().sum())
print(data["Year of sale"].value_counts(), data["Month of sale"].value_counts())
# Out:
# 'Year of sale' Non NaN Values: 195 'Month of sale' Non NaN Values: 195
# Year of sale
# 2007    102
# 2006     40
# 2005     27
# 2004     16
# 2008      9
# 2010      1
# Name: count, dtype: int64 Month of sale
# 11    27
# 3     24
# 12    20
# 10    19
# 8     18
# 7     17
# 9     15
# 6     15
# 4     13
# 5     11
# 1      8
# 2      8
# Name: count, dtype: int64

# %%
# Make some further checks:
print("'Type of property' Non NaN Values:", data["Type of property"].value_counts().sum())
data["Type of property"].value_counts()
# Out:
# 'Type of property' Non NaN Values: 267
# Type of property
# Apartment    259
# Office         8
# Name: count, dtype: int64

# %%
print("'Area (ft.)' Non NaN Values:", data["Area (ft.)"].value_counts().sum())
# Out:
# 'Area (ft.)' Non NaN Values: 267

# %% [markdown]
# The units of this column are in square feets. It isn't recommended to transform them, however, we will do this for practise purposes. Let's try displaying this column in square meters meeting the SI measurement system standards.

# %%
# Change the dtype of 'Area (ft.)': 
data["Area (ft.)"] = data["Area (ft.)"].astype("int")

# %%
# Transform the units knowing that 1 sq feet equals 0.09290304
factor = 0.09290304

# Check the square feet mean for verification reasons:
mean_sq_feet = data["Area (ft.)"].mean().round(2)
print("Expected Square Meter Mean:", round(mean_sq_feet * factor, 2))

# Transform into square meters and check the result:
data["Area (ft.)"] = data["Area (ft.)"] * factor
mean_sq_meter = data["Area (ft.)"].mean().round(2)
print("Actual Square Meter Mean:", round(mean_sq_meter, 2))
# Out:
# Expected Square Meter Mean: 86.93
# Actual Square Meter Mean: 86.93

# %%
data["Area (mt.)"] = data["Area (ft.)"]
data = data.drop(columns="Area (ft.)")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       267 non-null    object
#  1   Building                 267 non-null    category
#  2   Year of sale             195 non-null    object
#  3   Month of sale            195 non-null    object
#  4   Type of property         267 non-null    object
#  5   Property #               267 non-null    int32
#  6   Price                    267 non-null    object
#  7   Status                   195 non-null    object
#  8   Customer ID              195 non-null    object
#  9   Entity                   195 non-null    object
#  10  Name                     195 non-null    object
#  11  Surname                  195 non-null    object
#  12  Age at time of purchase  179 non-null    object
#  13  Interval                 178 non-null    object
#  14  Y                        178 non-null    object
#  15  M                        178 non-null    object
#  16  D                        178 non-null    object
#  17  Gender                   178 non-null    object
#  18  Country                  195 non-null    object
#  19  State                    181 non-null    object
#  20  Purpose                  195 non-null    object
#  21  Deal satisfaction        195 non-null    object
#  22  Mortgage                 195 non-null    object
#  23  Source                   195 non-null    object
#  24  Area (mt.)               267 non-null    float64
# dtypes: category(1), float64(1), int32(1), object(22)
# memory usage: 49.6+ KB

# %% [markdown]
# ### Missing Values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       267 non-null    object
#  1   Building                 267 non-null    category
#  2   Year of sale             195 non-null    object
#  3   Month of sale            195 non-null    object
#  4   Type of property         267 non-null    object
#  5   Property #               267 non-null    int32
#  6   Price                    267 non-null    object
#  7   Status                   195 non-null    object
#  8   Customer ID              195 non-null    object
#  9   Entity                   195 non-null    object
#  10  Name                     195 non-null    object
#  11  Surname                  195 non-null    object
#  12  Age at time of purchase  179 non-null    object
#  13  Interval                 178 non-null    object
#  14  Y                        178 non-null    object
#  15  M                        178 non-null    object
#  16  D                        178 non-null    object
#  17  Gender                   178 non-null    object
#  18  Country                  195 non-null    object
#  19  State                    181 non-null    object
#  20  Purpose                  195 non-null    object
#  21  Deal satisfaction        195 non-null    object
#  22  Mortgage                 195 non-null    object
#  23  Source                   195 non-null    object
#  24  Area (mt.)               267 non-null    float64
# dtypes: category(1), float64(1), int32(1), object(22)
# memory usage: 49.6+ KB

# %% [markdown]
# 19 out of 25 categories have missing values. This is the 76% of the columns. Since there isn't any more information about the data and domain expertise and since this project was created for practise reasons, we will drop some rows to see if the missing values are concentrated at the same rows.

# %%
# Drop the minimum number of rows and see what happens:
data = data.dropna(subset=["Year of sale"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 195 entries, 0 to 195
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       195 non-null    object
#  1   Building                 195 non-null    category
#  2   Year of sale             195 non-null    object
#  3   Month of sale            195 non-null    object
#  4   Type of property         195 non-null    object
#  5   Property #               195 non-null    int32
#  6   Price                    195 non-null    object
#  7   Status                   195 non-null    object
#  8   Customer ID              195 non-null    object
#  9   Entity                   195 non-null    object
#  10  Name                     195 non-null    object
#  11  Surname                  195 non-null    object
#  12  Age at time of purchase  178 non-null    object
#  13  Interval                 178 non-null    object
#  14  Y                        178 non-null    object
#  15  M                        178 non-null    object
#  16  D                        178 non-null    object
#  17  Gender                   178 non-null    object
#  18  Country                  195 non-null    object
#  19  State                    181 non-null    object
#  20  Purpose                  195 non-null    object
#  21  Deal satisfaction        195 non-null    object
#  22  Mortgage                 195 non-null    object
#  23  Source                   195 non-null    object
#  24  Area (mt.)               195 non-null    float64
# dtypes: category(1), float64(1), int32(1), object(22)
# memory usage: 37.7+ KB

# %% [markdown]
# This is interesting and it means that the 72 dropped observations had missing values at 76% of their columns. Let's see what happens with the remaining missing values.

# %%
# Identify rows with missing values and create a DataFrame containing only these rows: 
data_missing = data[data.isna().any(axis=1)]

# Make pandas show the initially collapsed columns:
pd.set_option("display.max_columns", 25)

data_missing
# Out:
# 0      ID Building Year of sale Month of sale Type of property  Property #  \
# 41   1032        1         2005             1        Apartment          32
# 58   2025        2         2007             2        Apartment          25
# 64   2005        2         2006             9        Apartment           5
# 76   3049        3         2007             4        Apartment          49
# 114  2003        2         2006            12        Apartment           3
# 139  3050        3         2006            11        Apartment          50
# 146  2019        2         2007             3        Apartment          19
# 147  2021        2         2007             4        Apartment          21
     NaN      NaN  NaN  NaN  NaN    NaN    USA
# 194                     NaN      NaN  NaN  NaN  NaN    NaN    USA
# 195                     NaN      NaN  NaN  NaN  NaN    NaN    USA
#
# 0         State     Purpose Deal satisfaction Mortgage   Source  Area (mt.)
# 179  California  Investment                 5       No   Agency   38.090246
# 180      Nevada  Investment                 5       No  Website  111.483648
# 181      Nevada  Investment                 4       No  Website   74.322432
# 182      Nevada  Investment                 5      Yes  Website   76.830814
# 183      Nevada  Investment                 1      Yes  Website   71.999856
# 184  California  Investment                 1      Yes  Website   71.999856
# 185  California  Investment                 5       No  Website  149.016476
# 186  California        Home                 3      Yes  Website   54.534084
# 187  California  Investment                 5       No  Website   70.234698
# 188  California  Investment                 5       No  Website   69.026959
# 189  California  Investment                 5       No  Website   76.830814
# 190  California  Investment                 5       No  Website  107.767526
# 191  California  Investment                 5       No  Website   69.026959
# 192  California  Investment                 5       No  Website  107.767526
# 193  California  Investment                 5       No  Website   58.064400
# 194  California  Investment                 5       No  Website   70.234698
# 195  California  Investment                 5       No  Website   58.064400

# %% [markdown]
# There is a pattern in missing values related to the 'Entity' column. Both the age of the person who makes the purchase and the gender don't matter since the person represents a firm and not a human.

# %%
data["Entity"].value_counts()
# Out:
# Entity
# Individual    178
# Firm           17
# Name: count, dtype: int64

# %% [markdown]
# Therefore, all 17 observations which include missing values are firms and not individuals. However, the lack of information about the year of construction is a limitation. The final conclusion doesn't consistute a problem if we want to check some individual related patterns. Dropping these 17 observations means we will end up with 178 purchases which made by individuals which is not bad at all depending on our purposes.

# %%
# Drop the firm purchases from the original data set:
data = data.dropna()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 178 entries, 0 to 177
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       178 non-null    object
#  1   Building                 178 non-null    category
#  2   Year of sale             178 non-null    object
#  3   Month of sale            178 non-null    object
#  4   Type of property         178 non-null    object
#  5   Property #               178 non-null    int32
#  6   Price                    178 non-null    object
#  7   Status                   178 non-null    object
#  8   Customer ID              178 non-null    object
#  9   Entity                   178 non-null    object
#  10  Name                     178 non-null    object
#  11  Surname                  178 non-null    object
#  12  Age at time of purchase  178 non-null    object
#  13  Interval                 178 non-null    object
#  14  Y                        178 non-null    object
#  15  M                        178 non-null    object
#  16  D                        178 non-null    object
#  17  Gender                   178 non-null    object
#  18  Country                  178 non-null    object
#  19  State                    178 non-null    object
#  20  Purpose                  178 non-null    object
#  21  Deal satisfaction        178 non-null    object
#  22  Mortgage                 178 non-null    object
#  23  Source                   178 non-null    object
#  24  Area (mt.)               178 non-null    float64
# dtypes: category(1), float64(1), int32(1), object(22)
# memory usage: 34.5+ KB

# %% [markdown]
# Let's get rid of some columns. For example, the "Type of property" column includes only two offices, whereas the rest of the observations are apartment-related. Assuming we want to focus on houses, let's remove observations where the "Type of property" is "office." Subsequently, we can consider dropping low cardinality columns (with few unique values) that might not be informative for our analysis. This helps reduce dimensionality and simplify the data set.
#
# Since this is a project for practice reasons and assuming the data table won't be needed for merging, and also assuming there is no need for customer analysis, we can further simplify the data by dropping high cardinality columns (with many unique values).
#
# In addition, there are three columns that seem redundant and hence highly correlated: "building's age at the time of purchase," "building's year of construction," and "building's age intervals." Knowing the year the building sold, either building's age or building's year of construction is sufficient. We can drop one of these. Consequently, the "month" and "day" of construction are also be unnecessary.

# %%
# Find the office observations:
office_index = data.loc[data["Type of property"] == "Office"].index

# And drop them from the data table:
data = data.drop(office_index, axis=0)

# Drop the low cardinality columns:
data = data.drop(columns=["Type of property", "Entity", "Status"])

# Drop the high cardinality columns:
data = data.drop(columns=["ID", "Property #", "Customer ID", "Name", "Surname"])

# Drop the redundant columns, both the "Interval" and the "Age at time of purchase" columns will be kept:
data = data.drop(columns=["Y", "M", "D"])

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 176 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Building                 176 non-null    category
#  1   Year of sale             176 non-null    object
#  2   Month of sale            176 non-null    object
#  3   Price                    176 non-null    object
#  4   Age at time of purchase  176 non-null    object
#  5   Interval                 176 non-null    object
#  6   Gender                   176 non-null    object
#  7   Country                  176 non-null    object
#  8   State                    176 non-null    object
#  9   Purpose                  176 non-null    object
#  10  Deal satisfaction        176 non-null    object
#  11  Mortgage                 176 non-null    object
#  12  Source                   176 non-null    object
#  13  Area (mt.)               176 non-null    float64
# dtypes: category(1), float64(1), object(12)
# memory usage: 19.6+ KB

# %% [markdown]
# Let's check the dtypes of the columns.

# %%
data["Price"] = data["Price"].astype("float")
data[["Age at time of purchase", "Year of sale", "Month of sale"]] = data[
["Age at time of purchase", "Year of sale", "Month of sale"]
].astype("int")
data["Building"] = data["Building"].astype("str")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 176 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Building                 176 non-null    object
#  1   Year of sale             176 non-null    int32
#  2   Month of sale            176 non-null    int32
#  3   Price                    176 non-null    float64
#  4   Age at time of purchase  176 non-null    int32
#  5   Interval                 176 non-null    object
#  6   Gender                   176 non-null    object
#  7   Country                  176 non-null    object
#  8   State                    176 non-null    object
#  9   Purpose                  176 non-null    object
#  10  Deal satisfaction        176 non-null    object
#  11  Mortgage                 176 non-null    object
#  12  Source                   176 non-null    object
#  13  Area (mt.)               176 non-null    float64
# dtypes: float64(2), int32(3), object(9)
# memory usage: 18.6+ KB

# %%
# Change "Age at time of purchse" column's name to make its meaning more clear:
data["Building age at time of purchase"] = data["Age at time of purchase"]
data = data.drop(columns="Age at time of purchase")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 176 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Building                          176 non-null    object
#  1   Year of sale                      176 non-null    int32
#  2   Month of sale                     176 non-null    int32
#  3   Price                             176 non-null    float64
#  4   Interval                          176 non-null    object
#  5   Gender                            176 non-null    object
#  6   Country                           176 non-null    object
#  7   State                             176 non-null    object
#  8   Purpose                           176 non-null    object
#  9   Deal satisfaction                 176 non-null    object
#  10  Mortgage                          176 non-null    object
#  11  Source                            176 non-null    object
#  12  Area (mt.)                        176 non-null    float64
#  13  Building age at time of purchase  176 non-null    int32
# dtypes: float64(2), int32(3), object(9)
# memory usage: 18.6+ KB

# %% [markdown]
# And this is the final df.

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Manipulate the data:
bar_data = data["Interval"].value_counts()
bar_data_sorted = bar_data.index.sort_values()

# Create the bar chart:
plt.bar(bar_data_sorted, bar_data[bar_data_sorted])

# Customize bar chart:
plt.xlabel("Building's Age Intervals")
plt.ylabel("Frequency")
plt.title("Building's Age Intervals Bar Chart");

# %% [markdown]
# The distribution is spread out, with a longer tail towards the older age buildings (right skew). This suggests there's a larger variation in offers of older buildings.

# %%
data["Building age at time of purchase"].describe()
# Out:
# count    176.000000
# mean      46.136364
# std       12.874055
# min       19.000000
# 25%       37.000000
# 50%       45.000000
# 75%       55.000000
# max       76.000000
# Name: Building age at time of purchase, dtype: float64

# %%
# Create the histogram:
plt.hist(data["Building age at time of purchase"], edgecolor="black", bins=10)

# Create axis labels and title:
plt.xlabel("Building's Age")
plt.ylabel("Frequency")
plt.title("Distribution of the Building's Age at Time of Purchase")

# Customize the appearence of the x axis: 
custom_xticks = range(15, 80, 5)
bins = range(15, 80, 5)
plt.xticks(ticks=bins, labels=custom_xticks);

# %% [markdown]
# The histogram confirms a right-skewed distribution, with most buildings been more recent. The interquartile range (IQR) is 55 - 37 = 18 years. This means that the middle 50% age of the buildings were between 37 and 55 years old. The mean is greater than the median which is also expected since there is a positive skewness.

# %%
# Create a boxplot:
plt.boxplot(data["Building age at time of purchase"], vert=False)
plt.xlabel("Building's Age")
plt.title("Distribution of the Building's Age at Time of Purchase (Boxplot)");

# %% [markdown]
# The boxplot shows the same things have discussed already. It can be optically seen that the median is left-shifted indicating a right skew in the age distribution. The information about the IQR is not very clear. Knowing that the $IQR = 18$, this means that the outliers lie below the age of $37 - 1.5*IQR$, i.e., 10 years old and above the $Q3 + 1.5*IQR$, i.e., 82 years old. Therefore, there are no outliers inside this column. This is the reason the whiskers show the minimum and maximum osbervation age instead of the $1.5*IQR$ rule limits. The final conclusion is that the visualizations in conjunction with descriptive statistics can offer a more complete understanding.

# %%
data["Price"].describe()
# Out:
# count       176.000000
# mean     270609.389157
# std       78041.312894
# min      153466.712400
# 25%      215215.627100
# 50%      245196.730400
# 75%      307714.665900
# max      503790.230800
# Name: Price, dtype: float64

# %%
# Scale the price:
price_scaled = data["Price"] / 1000

# Create the histogram:
plt.hist(price_scaled, edgecolor="black", bins=20)
plt.xlabel("Price in $ (X1000)")
plt.ylabel("Frequency")
plt.title("Distribution of Price")

# Fix the appearence of the x axis: 
custom_xticks = range(125, 525, 25)
bins = range(125, 525, 25)
plt.xticks(ticks=bins, labels=custom_xticks, rotation=60);

# %% [markdown]
# The histogram reveals a positive skew. This aligns with real-world expectations, where most buyers tend to choose more affordable options. Consequently, the market offers a wider range of economical choices to meet this demand.

# %%
cols_for_cor = data[["Price", "Building age at time of purchase", "Area (mt.)"]]
cols_for_cor.corr()
# Out:
# 0                                    Price  Building age at time of purchase  \
# 0
# Price                             1.000000                         -0.189767
# Building age at time of purchase -0.189767                          1.000000
# Area (mt.)                        0.938710                         -0.190079
#
# 0                                 Area (mt.)
# 0
# Price                               0.938710
# Building age at time of purchase   -0.190079
# Area (mt.)                          1.000000

# %%
# Create a scatterplot of Price VS Building age:
sns.scatterplot(x="Price", y="Building age at time of purchase", data=data, hue="Gender")

# Customize the scatterplot:
plt.xticks(rotation=45)
plt.xlabel("Price")
plt.ylabel("Building's Age")
plt.title("Scatter Plot: Price vs. Building's Age");

# %% [markdown]
# A negative correlation between the building's age and the price would expected. The scatter plot reveals what the corr() method has already revealed. There is a sligh negative correlation between the property's age and the price paid for the property.

# %%
# Create a scatterplot of Price VS Area:
sns.scatterplot(x="Price", y="Area (mt.)", data=data, hue="Interval") 

# Customize the scatterplot:
plt.xticks(rotation=45)
plt.xlabel("Price")
plt.ylabel("Area in Square Meters")
plt.title("Scatter Plot: Price vs. Area in Square Meters")
plt.legend(title="Age Intervals");

# %% [markdown]
# This result is also as expected.

# %%
# Save the data table for future use:
data.to_csv("california_housing.csv", index=False)
